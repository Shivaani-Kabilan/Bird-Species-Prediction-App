# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Library imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.image import imread
import cv2
import random
from os import listdir
from sklearn.preprocessing import  LabelBinarizer
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array, array_to_img
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Flatten, Dropout, Dense
from sklearn.model_selection import train_test_split

# %%
# Plotting 12 images to check dataset
plt.figure(figsize=(12,12))
path = "/content/drive/My Drive/Bird Speciees Dataset/AMERICAN GOLDFINCH"
for i in range(1,17):
    plt.subplot(4,4,i)
    plt.tight_layout()
    rand_img = imread(path +'/'+ random.choice(sorted(listdir(path))))
    plt.imshow(rand_img)
    plt.xlabel(rand_img.shape[1], fontsize = 10)
    plt.ylabel(rand_img.shape[0], fontsize = 10)

# %%
# Setting path and creating empty list
dir = "/content/drive/My Drive/Bird Speciees Dataset"
root_dir = listdir(dir)
image_list, label_list = [], []

# %%
# Reading and converting image to numpy array
for directory in root_dir:
  for files in listdir(f"{dir}/{directory}"):
    image_path = f"{dir}/{directory}/{files}"
    image = cv2.imread(image_path)
    image = img_to_array(image)
    image_list.append(image)
    label_list.append(directory)

# %%
# Visualize the number of classes count
label_counts = pd.DataFrame(label_list).value_counts()
label_counts
# Out:
# AMERICAN GOLDFINCH    143
# EMPEROR PENGUIN       139
# DOWNY WOODPECKER      137
# FLAMINGO              132
# CARMINE BEE-EATER     131
# BARN OWL              129
# dtype: int64

# %%
# Storing number of classes
num_classes = len(label_counts)
num_classes
# Out:
# 6

# %%
# Checking input image shape
image_list[0].shape
# Out:
# (224, 224, 3)

# %%
# Checking labels shape 
label_list = np.array(label_list)
label_list.shape
# Out:
# (811,)

# %%
# Splitting dataset
x_train, x_test, y_train, y_test = train_test_split(image_list, label_list, test_size=0.2, random_state = 10)

# %%
# Normalize and reshape data
x_train = np.array(x_train, dtype=np.float16) / 225.0
x_test = np.array(x_test, dtype=np.float16) / 225.0
x_train = x_train.reshape( -1, 224,224,3)
x_test = x_test.reshape( -1, 224,224,3)

# %%
# Label binarizing
lb = LabelBinarizer()
y_train = lb.fit_transform(y_train)
y_test = lb.fit_transform(y_test)
print(lb.classes_)
# Out:
# ['AMERICAN GOLDFINCH' 'BARN OWL' 'CARMINE BEE-EATER' 'DOWNY WOODPECKER'
#  'EMPEROR PENGUIN' 'FLAMINGO']

# %%
# Splitting the training data set into training and validation data sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2)

# %%
# Building model architecture
model = Sequential()
model.add(Conv2D(8, (3, 3), padding="same",input_shape=(224,224,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Conv2D(16, (3, 3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(32, (3, 3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(32, activation="relu"))
model.add(Dense(num_classes, activation="softmax"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 224, 224, 8)       224
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 8)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 74, 74, 16)        1168
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 37, 37, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 10368)             0
# _________________________________________________________________
# dense (Dense)                (None, 32)                331808
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 198
# =================================================================
# Total params: 338,038
# Trainable params: 338,038
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling model
model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0005),metrics=['accuracy'])

# %%
# Training the model
epochs = 50
batch_size = 128
history = model.fit(x_train, y_train, batch_size = batch_size, epochs = epochs, validation_data = (x_val, y_val))
# Out:
# Epoch 1/50
# 5/5 [==============================] - 32s 238ms/step - loss: 1.7961 - accuracy: 0.1911 - val_loss: 1.6857 - val_accuracy: 0.3769
# Epoch 2/50
# 5/5 [==============================] - 0s 95ms/step - loss: 1.6703 - accuracy: 0.3571 - val_loss: 1.6456 - val_accuracy: 0.2385
# Epoch 3/50
# 5/5 [==============================] - 0s 94ms/step - loss: 1.5812 - accuracy: 0.3668 - val_loss: 1.5087 - val_accuracy: 0.4538
# Epoch 4/50
# 5/5 [==============================] - 0s 96ms/step - loss: 1.4822 - accuracy: 0.4556 - val_loss: 1.3769 - val_accuracy: 0.4538
# Epoch 5/50
# 5/5 [==============================] - 0s 99ms/step - loss: 1.3394 - accuracy: 0.5232 - val_loss: 1.2389 - val_accuracy: 0.6000
# Epoch 6/50
# 5/5 [==============================] - 0s 96ms/step - loss: 1.2178 - accuracy: 0.6178 - val_loss: 1.1841 - val_accuracy: 0.5615
# Epoch 7/50
# 5/5 [==============================] - 0s 96ms/step - loss: 1.1232 - accuracy: 0.6274 - val_loss: 1.0517 - val_accuracy: 0.6154
# Epoch 8/50
# 5/5 [==============================] - 1s 102ms/step - loss: 1.0050 - accuracy: 0.6892 - val_loss: 0.9433 - val_accuracy: 0.6846
# Epoch 9/50
# 5/5 [==============================] - 0s 97ms/step - loss: 0.9001 - accuracy: 0.7278 - val_loss: 0.9785 - val_accuracy: 0.6462
# Epoch 10/50
# 5/5 [==============================] - 0s 97ms/step - loss: 0.8567 - accuracy: 0.7085 - val_loss: 0.8390 - val_accuracy: 0.6615
# Epoch 11/50
# 5/5 [==============================] - 1s 115ms/step - loss: 0.7081 - accuracy: 0.7761 - val_loss: 0.8528 - val_accuracy: 0.6538
# Epoch 12/50
# 5/5 [==============================] - 0s 99ms/step - loss: 0.7404 - accuracy: 0.7432 - val_loss: 0.7233 - val_accuracy: 0.7538
# Epoch 13/50
# 5/5 [==============================] - 0s 98ms/step - loss: 0.6205 - accuracy: 0.7954 - val_loss: 0.7383 - val_accuracy: 0.7077
# Epoch 14/50
# 5/5 [==============================] - 0s 96ms/step - loss: 0.5329 - accuracy: 0.8301 - val_loss: 0.6366 - val_accuracy: 0.7846
# Epoch 15/50
# 5/5 [==============================] - 0s 96ms/step - loss: 0.4932 - accuracy: 0.8649 - val_loss: 0.6476 - val_accuracy: 0.7538
# Epoch 16/50
# 5/5 [==============================] - 1s 101ms/step - loss: 0.4754 - accuracy: 0.8359 - val_loss: 0.6093 - val_accuracy: 0.8000
# Epoch 17/50
# 5/5 [==============================] - 0s 98ms/step - loss: 0.4142 - accuracy: 0.8668 - val_loss: 0.6303 - val_accuracy: 0.8000
# Epoch 18/50
# 5/5 [==============================] - 0s 98ms/step - loss: 0.4352 - accuracy: 0.8649 - val_loss: 0.5512 - val_accuracy: 0.8000
# Epoch 19/50
# 5/5 [==============================] - 0s 95ms/step - loss: 0.3914 - accuracy: 0.8475 - val_loss: 0.6529 - val_accuracy: 0.7615
# Epoch 20/50
# 5/5 [==============================] - 0s 98ms/step - loss: 0.3265 - accuracy: 0.9015 - val_loss: 0.5294 - val_accuracy: 0.8154
# Epoch 21/50
# 5/5 [==============================] - 0s 96ms/step - loss: 0.3180 - accuracy: 0.9093 - val_loss: 0.5418 - val_accuracy: 0.8154
# Epoch 22/50
# 5/5 [==============================] - 0s 93ms/step - loss: 0.3193 - accuracy: 0.8861 - val_loss: 0.5466 - val_accuracy: 0.8000
# Epoch 23/50
# 5/5 [==============================] - 0s 97ms/step - loss: 0.3029 - accuracy: 0.9093 - val_loss: 0.5172 - val_accuracy: 0.8462
# Epoch 24/50
# 5/5 [==============================] - 0s 95ms/step - loss: 0.2818 - accuracy: 0.9015 - val_loss: 0.4900 - val_accuracy: 0.8462
# Epoch 25/50
# 5/5 [==============================] - 0s 96ms/step - loss: 0.2321 - accuracy: 0.9363 - val_loss: 0.5033 - val_accuracy: 0.8000
# Epoch 26/50
# 5/5 [==============================] - 1s 120ms/step - loss: 0.1971 - accuracy: 0.9537 - val_loss: 0.5670 - val_accuracy: 0.8077
# Epoch 27/50
# 5/5 [==============================] - 0s 97ms/step - loss: 0.2217 - accuracy: 0.9324 - val_loss: 0.4839 - val_accuracy: 0.8231
# Epoch 28/50
# 5/5 [==============================] - 0s 97ms/step - loss: 0.1912 - accuracy: 0.9498 - val_loss: 0.6043 - val_accuracy: 0.8000
# Epoch 29/50
# 5/5 [==============================] - 0s 98ms/step - loss: 0.1946 - accuracy: 0.9421 - val_loss: 0.5309 - val_accuracy: 0.8231
# Epoch 30/50
# 5/5 [==============================] - 0s 98ms/step - loss: 0.1623 - accuracy: 0.9614 - val_loss: 0.5086 - val_accuracy: 0.8308
# Epoch 31/50
# 5/5 [==============================] - 0s 98ms/step - loss: 0.1549 - accuracy: 0.9653 - val_loss: 0.5040 - val_accuracy: 0.8077
# Epoch 32/50
# 5/5 [==============================] - 0s 96ms/step - loss: 0.1233 - accuracy: 0.9691 - val_loss: 0.5665 - val_accuracy: 0.8077
# Epoch 33/50
# 5/5 [==============================] - 0s 98ms/step - loss: 0.1581 - accuracy: 0.9498 - val_loss: 0.5288 - val_accuracy: 0.8154
# Epoch 34/50
# 5/5 [==============================] - 0s 93ms/step - loss: 0.1087 - accuracy: 0.9807 - val_loss: 0.5531 - val_accuracy: 0.8231
# Epoch 35/50
# 5/5 [==============================] - 0s 97ms/step - loss: 0.1135 - accuracy: 0.9788 - val_loss: 0.5213 - val_accuracy: 0.8231
# Epoch 36/50
# 5/5 [==============================] - 0s 97ms/step - loss: 0.1152 - accuracy: 0.9710 - val_loss: 0.5637 - val_accuracy: 0.8077
# Epoch 37/50
# 5/5 [==============================] - 0s 97ms/step - loss: 0.0905 - accuracy: 0.9846 - val_loss: 0.5106 - val_accuracy: 0.8154
# Epoch 38/50
# 5/5 [==============================] - 0s 96ms/step - loss: 0.0738 - accuracy: 0.9923 - val_loss: 0.5383 - val_accuracy: 0.8154
# Epoch 39/50
# 5/5 [==============================] - 0s 92ms/step - loss: 0.1027 - accuracy: 0.9788 - val_loss: 0.4890 - val_accuracy: 0.8308
# Epoch 40/50
# 5/5 [==============================] - 0s 96ms/step - loss: 0.1048 - accuracy: 0.9749 - val_loss: 0.6359 - val_accuracy: 0.7769
# Epoch 41/50
# 5/5 [==============================] - 0s 98ms/step - loss: 0.1056 - accuracy: 0.9710 - val_loss: 0.5100 - val_accuracy: 0.8231
# Epoch 42/50
# 5/5 [==============================] - 0s 95ms/step - loss: 0.0880 - accuracy: 0.9826 - val_loss: 0.4915 - val_accuracy: 0.8308
# Epoch 43/50
# 5/5 [==============================] - 0s 99ms/step - loss: 0.0609 - accuracy: 0.9942 - val_loss: 0.5399 - val_accuracy: 0.8231
# Epoch 44/50
# 5/5 [==============================] - 0s 99ms/step - loss: 0.0481 - accuracy: 0.9981 - val_loss: 0.5138 - val_accuracy: 0.8154
# Epoch 45/50
# 5/5 [==============================] - 0s 97ms/step - loss: 0.0485 - accuracy: 0.9942 - val_loss: 0.5497 - val_accuracy: 0.8308
# Epoch 46/50
# 5/5 [==============================] - 0s 96ms/step - loss: 0.0570 - accuracy: 0.9923 - val_loss: 0.5144 - val_accuracy: 0.8231
# Epoch 47/50
# 5/5 [==============================] - 0s 96ms/step - loss: 0.0403 - accuracy: 0.9981 - val_loss: 0.5294 - val_accuracy: 0.8308
# Epoch 48/50
# 5/5 [==============================] - 0s 98ms/step - loss: 0.0351 - accuracy: 1.0000 - val_loss: 0.5697 - val_accuracy: 0.8231
# Epoch 49/50
# 5/5 [==============================] - 0s 100ms/step - loss: 0.0349 - accuracy: 0.9961 - val_loss: 0.5697 - val_accuracy: 0.8231
# Epoch 50/50
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0620 - accuracy: 0.9884 - val_loss: 0.7176 - val_accuracy: 0.7923

# %%
# Saving model
model.save("/content/drive/My Drive/bird_species.h5")

# %%
#Plot the training history
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

# %%
#Plot the loss history
plt.figure(figsize=(12, 5))
plt.plot(history.history['loss'], color='r')
plt.plot(history.history['val_loss'], color='b')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

# %%
# Calculating test accuracy
scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# 6/6 [==============================] - 0s 34ms/step - loss: 0.4740 - accuracy: 0.8466
# Test Accuracy: 84.66257452964783

# %%
# Storing predictions
y_pred = model.predict(x_test)

# %%
# Plotting image to compare
img = array_to_img(x_test[5])
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F64BCB09750>

# %%
# Finding max value from predition list and comaparing original value vs predicted
labels = lb.classes_
print(labels)
print("Originally : ",labels[np.argmax(y_test[5])])
print("Predicted : ",labels[np.argmax(y_pred[5])])
# Out:
# ['AMERICAN GOLDFINCH' 'BARN OWL' 'CARMINE BEE-EATER' 'DOWNY WOODPECKER'
#  'EMPEROR PENGUIN' 'FLAMINGO']
# Originally :  AMERICAN GOLDFINCH
# Predicted :  AMERICAN GOLDFINCH

# %%
# Plotting image to compare
img = array_to_img(x_test[50])
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F64BCA75910>

# %%
# Finding max value from predition list and comaparing original value vs predicted
labels = lb.classes_
print(labels)
print("Originally : ",labels[np.argmax(y_test[50])])
print("Predicted : ",labels[np.argmax(y_pred[50])])
# Out:
# ['AMERICAN GOLDFINCH' 'BARN OWL' 'CARMINE BEE-EATER' 'DOWNY WOODPECKER'
#  'EMPEROR PENGUIN' 'FLAMINGO']
# Originally :  EMPEROR PENGUIN
# Predicted :  EMPEROR PENGUIN

# %%
# Plotting image to compare
img = array_to_img(x_test[105])
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F64BCA3B490>

# %%
# Finding max value from predition list and comaparing original value vs predicted
labels = lb.classes_
print(labels)
print("Originally : ",labels[np.argmax(y_test[105])])
print("Predicted : ",labels[np.argmax(y_pred[105])])
# Out:
# ['AMERICAN GOLDFINCH' 'BARN OWL' 'CARMINE BEE-EATER' 'DOWNY WOODPECKER'
#  'EMPEROR PENGUIN' 'FLAMINGO']
# Originally :  BARN OWL
# Predicted :  BARN OWL
